# %%
include("../reconstruction_probability.jl")
# Out:
# reconstruction_probability (generic function with 1 method)

# %% [markdown]
# The energy of this model is defined as follows:
#
# $$ E = - \frac{1}{\lambda} log \left( \sum_{\mu = 1}^{P} exp( \lambda \xi^\mu \cdot x) \right), $$
# where the factor $ \xi^\mu \cdot x $ is the overlap between the $\mu$-th original pattern and the configuration x. <br>
#
# Now, if we change the sign of the $k$-th spin, we obtain that the overlap variation is:
# $$
# \Delta overlap = overlap_{fin} - overlap_{in} = \left(\sum_{i \neq k}\xi_i^\mu x_i + \xi_k^\mu (-x_k)\right) - \left(\sum_{i \neq k}\xi_i^\mu x_i + \xi_k^\mu x_k\right)\\
# = -2\xi_{k}^{\mu}x_k  $$.
#
# Thus, the variation in the energy can be calculated as:
# $$ \Delta E \equiv E_f - E_i = - \frac{1}{\lambda} log \left( \sum_{\mu = 1}^{P} exp( \lambda \cdot overlap_{in}^\mu) \right)
# + \frac{1}{\lambda} log \left( \sum_{\mu = 1}^{P} exp( \lambda \cdot overlap_{fin}^\mu) \right)\\
# = - \frac{1}{\lambda} \left[log \left(\sum_{\mu = 1}^{P} exp(\lambda \cdot overlap_{fin}^\mu \right)
# - log \left(\sum_{\mu = 1}^{P} exp(\lambda \cdot overlap_{in}^\mu \right)\right]\\
# = -\frac{1}{\lambda} \left[ log \left( \frac{\sum_{\mu = 1}^{P} exp(\lambda \cdot overlap_{fin}^\mu)}{\sum_{\mu = 1}^{P} exp(\lambda \cdot overlap_{in}^\mu)} \right) \right].
# $$
# We have that:
# $$ overlap_{fin}^\mu = overlap_{in}^\mu - 2\xi_{k}^{\mu}x_k. $$
# Hence:
# $$\Delta E =  -\frac{1}{\lambda} \left[ log \left( \frac{\sum_{\mu = 1}^{P} exp(\lambda \cdot overlap_{in}^\mu)exp(-2\lambda\xi_{k}^{\mu}x_k) }{\sum_{\mu = 1}^{P} exp(\lambda \cdot overlap_{in}^\mu)} \right) \right] $$

# %% [markdown]
# @time begin
#     N = 100
#     α = 0.1
#     M = round(Int, N * α)
#     p = 0.2
#     ξ = generate_patterns(M, N)
#     σ = perturb(ξ[:, 1], p)
#     nsweeps = 100
#     overlaps = zeros(nsweeps)
#
#     for sweep in 1:nsweeps
#         σ, fliprate = metropolis(σ, ξ)
#         overlaps[sweep] = overlap(σ, ξ[:,1])/N
#         fliprate <= 0 && break
#     end
#
# end

# %% [markdown]
# function metro(N::Int, M::Int, σ::AbstractVector, ξ::AbstractMatrix, β = 10)
#
#     fliprate = 0
#
#     for n in 1:N
#         i = rand(1:N)
#         ΔE = 0
#         for μ in 1:M
#             orig_ξ = ξ[:, μ]
#             overlap_in = overlap( orig_ξ, σ )
#             ΔE -= exp( overlap_in ) * ( exp( -2 * orig_ξ[i] * σ[i] ) - 1 )
#         end
#
#         if ΔE < 0 || rand() < exp( - β * ΔE)
#             σ[i] *= -1
#             fliprate += 1
#         end
#     end
#
#     return σ, fliprate/N
# end

# %% [markdown]
# function reconstruction_prob(N::Int, pp::AbstractVector, α, nsweeps,
#                              nsamples, β = 10, earlystop = 0)
#     M = round(Int, N * α)
#
#     len_pp = length(pp)
#     probs = zeros(len_pp)
#     error_bars = zeros(len_pp)
#     magnetization = zeros(len_pp)
#
#     for i in 1:len_pp
#         probs_over_samples = zeros(nsamples)
#         #count = 0
#         ms = zeros(nsamples)
#
#         for sample in 1:nsamples
#             ξ = generate_patterns(M, N)
#
#             k = rand(1:M)
#             σ = ξ[:, k]
#             perturbed_σ = perturb(σ, pp[i])
#
#             perturbed_σ = monte_carlo(perturbed_σ, ξ, nsweeps, earlystop, β)
#
#             m = overlap(perturbed_σ, σ)
#             #print(m)
#             if m >= N * 0.98
#                 probs_over_samples[sample] = 1
#                 #count += 1
#             end
#             ms[sample] = m
#         end
#         probs[i] = Statistics.mean(probs_over_samples)
#         error_bars[i] = Statistics.std(probs_over_samples)/sqrt(nsamples)
#         magnetization[i] = Statistics.mean(ms)
#     end
#
#     return probs, error_bars, magnetization
# end

# %% [markdown]
# NN = [50, 100]
# pp = range( 0.1, 0.7, length = 25 )
# α = 0.1
# nsweeps = 20
# β = 10^3
# nsamples = 1500
# earlystop = 0
#
# for i in 1:length(NN)
#     N = NN[i]
#     p, e, m = reconstruction_prob(N, pp, α, nsweeps, nsamples, β, earlystop)
#
#     fig = plot(pp, p, size = (500,300), markershape =:circle, label = "N = $N, α = $α",
#         yerrors = e, xlabel = "p", ylabel = "P_reconst")
#     display(fig)
#
#     #io = open("julia_data/alpha_01/probsN"*"$N"*".txt", "w") do io
#      #     writedlm(io, [p e m])
#     #end
# end

# %%
NN = [50] 
α = 100
pp = range(0.05, 0.95, length = 22)
@time reconstruction_probability(NN, α; pp = pp, show = true, save = false, nsamples = 10^3, thr = 0.8)
# Out:
# InterruptException:
#
# Stacktrace:
#   [1] Array
#     @ ./boot.jl:459 [inlined]
#   [2] Array
#     @ ./boot.jl:467 [inlined]
#   [3] similar
#     @ ./array.jl:378 [inlined]
#   [4] similar
#     @ ./abstractarray.jl:791 [inlined]
#   [5] reducedim_initarray(A::Matrix{Int64}, region::Int64, init::Int64, #unused#::Type{Int64})
#     @ Base ./reducedim.jl:92
#   [6] reducedim_initarray
#     @ ./reducedim.jl:93 [inlined]
#   [7] reducedim_init
#     @ ./reducedim.jl:184 [inlined]
#   [8] _mapreduce_dim
#     @ ./reducedim.jl:336 [inlined]
#   [9] #mapreduce#725
#     @ ./reducedim.jl:322 [inlined]
#  [10] #_sum#755
#     @ ./reducedim.jl:916 [inlined]
#  [11] _sum
#     @ ./reducedim.jl:916 [inlined]
#  [12] #_sum#754
#     @ ./reducedim.jl:915 [inlined]
#  [13] _sum
#     @ ./reducedim.jl:915 [inlined]
#  [14] #sum#732
#     @ ./reducedim.jl:889 [inlined]
#  [15] energy_variation(σ::Vector{Int64}, ξ::Matrix{Int64}, i::Int64, λ::Int64)
#     @ Main.MHB ~/Desktop/Physics of Data/Thesis/codes/Modern Hopfield/modern_hopfield_binary.jl:47
#  [16] metropolis(σ::Vector{Int64}, ξ::Matrix{Int64}, β::Int64, λ::Int64)
#     @ Main.MHB ~/Desktop/Physics of Data/Thesis/codes/Modern Hopfield/modern_hopfield_binary.jl:62
#  [17] #monte_carlo#1
#     @ ~/Desktop/Physics of Data/Thesis/codes/Modern Hopfield/modern_hopfield_binary.jl:77 [inlined]
#  [18] one_reconstruction_probability(N::Int64, pp::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, α::Int64, nsamples::Int64; nsweeps::Int64, β::Int64, earlystop::Int64, thr::Float64, λ::Int64)
#     @ Main ~/Desktop/Physics of Data/Thesis/codes/Modern Hopfield/Critical Noise/reconstruction_probability.jl:31
#  [19] reconstruction_probability(NN::Vector{Int64}, α::Int64; pp::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, nsweeps::Int64, β::Int64, nsamples::Int64, earlystop::Int64, thr::Float64, λ::Int64, show::Bool, save::Bool)
#     @ Main ~/Desktop/Physics of Data/Thesis/codes/Modern Hopfield/Critical Noise/reconstruction_probability.jl:64
#  [20] top-level scope
#     @ ./timing.jl:220 [inlined]
#  [21] top-level scope
#     @ ./In[18]:0
#  [22] eval
#     @ ./boot.jl:373 [inlined]
#  [23] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1196

# %%
pp = readdlm("../julia_data/reconstruction_prob/alpha_100/probsN30.txt")[:,1]
p50 = readdlm("../julia_data/reconstruction_prob/alpha_100/probsN30.txt")[:,2]
e50 = readdlm("../julia_data/reconstruction_prob/alpha_100/probsN30.txt")[:,3]
# Out:
# 22-element Vector{Float64}:
#  0.0
#  0.0001428571428571429
#  0.0006690534063988518
#  0.0013466174614981208
#  0.002201060828765004
#  0.0030584249381995074
#  0.004029255445647071
#  0.004764526149659933
#  0.005451142933357844
#  0.00585616702670481
#  0.005973114503421272
#  0.005787669702039663
#  0.005334663168035872
#  0.004572228360629012
#  0.0038622377262450404
#  0.002781013809234015
#  0.002108287685523693
#  0.0012783451791080673
#  0.0007409274380889091
#  0.0003193469883333442
#  0.00014285714285714287
#  0.0

# %%
fig = plot(pp, p50, markershape =:circle, yerrors = e50,
    xlabel = "p (noise)", ylabel = "Reconstruction prob.",
    title = "α = 100")
