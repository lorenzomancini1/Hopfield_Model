# %% [markdown]
# # We define the critical probability as
# $$
# p_c(N, \alpha) := \left\{p: \mathbb{P}^{reconst}_{N, \alpha}(p) = \frac{1}{2} \right\},
# $$
# that is, the corruption probability such that the reconstruction probability is equal to 0.5. <br>
# Thus, taking the $\lim_{N \to \infty}$, we define:
# $$
# p_c(\alpha) = \lim_{N \to \infty} p_c(N, \alpha).
# $$
# Assuming that:
# $$
# p_c(N, \alpha) = p_c(\alpha) + \frac{1}{N} a + \left(\frac{1}{N^2}\right)b
# $$
# **our goal is to determine $p_c(\alpha)$**.<br>
# In order to achieve this, we need to fit the $\mathbb{P}^{reconst}_{N, \alpha}(p)$ function:
# $$
# \mathbb{P}^{reconst}_{N, \alpha}(p) = exp[q_{N, \alpha} + {a_{N, \alpha}p + b_{N, \alpha} p^2 + c_{N, \alpha} p^3} + d_{N, \alpha} p^4 + e_{N, \alpha} p^5 + f_{N, \alpha} p^6]
# $$

# %%
import sys
sys.path.insert(0, '../../../')

# %%
import find_critical_noise as CN
import numpy as np
import matplotlib.pyplot as plt
import random
import scipy.optimize

# %%
x = []
y = []
yerr = []

# %%
NN = [200, 700, 1000, 1500]
α = 0.14
pcN, pcNerr, pc014, dpc014 =  CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit = False, plot_reg = True, errorbar = True)
x.append(α)
y.append(pc014)
yerr.append(dpc014)

# %%
NN = [1000, 1200, 1500, 2000]
α = 0.135
pcN, pcNerr, pc0135, dpc0135 =  CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg = True, errorbar = True, skip = 1)
x.append(α)
y.append(pc0135)
yerr.append(dpc0135)

# %%
NN = [200, 700, 1000, 1500]
α = 0.13
pcN, pcNerr, pc013, dpc013 =  CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg = True, errorbar = True)
x.append(α)
y.append(pc013)
yerr.append(dpc013)

# %%
NN = [200, 700, 1000, 1500]
α = 0.12
pcN, pcNerr, pc012, dpc012 =  CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg = True, errorbar = True)
x.append(α)
y.append(pc012)
yerr.append(dpc012)

# %%
NN = [200, 700, 1000, 1500]
α = 0.11
pcN, pcNerr, pc011, dpc011 =  CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg = True, errorbar = True)
x.append(α)
y.append(pc011)
yerr.append(dpc011)

# %%
NN = [200, 700, 1000, 1500]
α = 0.1
pcN, pcNerr, pc01, dpc01 =  CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg = True, errorbar = True)
x.append(α)
y.append(pc01)
yerr.append(dpc01)

# %%
NN = [200, 700, 1000, 1500]
α = 0.09
pcN, pcNerr, pc009, dpc009 =  CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg = True, errorbar = True)
x.append(α)
y.append(pc009)
yerr.append(dpc009)

# %%
NN = [200, 700, 1000, 1500]
α = 0.08
pcN, pcNerr, pc008, dpc008 =  CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg = True, errorbar = True)
x.append(α)
y.append(pc008)
yerr.append(dpc008)

# %%
NN = [200, 700, 1000, 1500]
α = 0.07
pcN, pcNerr, pc007, dpc007 =  CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg = True, errorbar = True)
x.append(α)
y.append(pc007)
yerr.append(dpc007)

# %%
NN = [200, 700, 1000, 1500]
α = 0.06
pcN, pcNerr, pc006, dpc006 =  CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg = True, errorbar = True, d = 1)
x.append(α)
y.append(pc006)
yerr.append(dpc006)

# %%
NN = [200, 700, 1000, 1500]
α = 0.05
pcN, pcNerr, pc005, dpc005 =  CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg = True, errorbar = True)
x.append(α)
y.append(pc005)
yerr.append(dpc005)

# %%
NN = [200, 700, 1000, 1500]
α = 0.04
pcN, pcNerr, pc004, dpc004 =  CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg = True, errorbar = True)
x.append(α)
y.append(pc004)
yerr.append(dpc004)

# %%
NN = [200, 700, 1000, 1500]
α = 0.03
pcN, pcNerr, pc003, dpc003 =  CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg = True, errorbar = True)
x.append(α)
y.append(pc003)
yerr.append(dpc003)

# %%
NN = [200, 700, 1000, 1500]
α = 0.02
pcN, pcNerr, pc002, dpc002 =  CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg = True, errorbar = True)
x.append(α)
y.append(pc002)
yerr.append(dpc002)

# %%
y = list(map(lambda i: max(0, i), y))
plt.plot(x, y, linestyle = "None", marker = "o")
data = list(zip(x, y, yerr))
np.savetxt("julia_data/results.txt", data)
