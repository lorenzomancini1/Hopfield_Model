# %% [markdown]
# # We define the critical probability as
# $$
# p_c(N, \alpha) := \left\{p: \mathbb{P}^{reconst}_{N, \alpha}(p) = \frac{1}{2} \right\},
# $$
# that is, the corruption probability such that the reconstruction probability is equal to 0.5. <br>
# Thus, taking the $\lim_{N \to \infty}$, we define:
# $$
# p_c(\alpha) = \lim_{N \to \infty} p_c(N, \alpha).
# $$
# Assuming that:
# $$
# p_c(N, \alpha) = p_c(\alpha) + \frac{1}{N} a + \left(\frac{1}{N^2}\right)b
# $$
# **our goal is to determine $p_c(\alpha)$**.<br>
# In order to achieve this, we need to fit the $\mathbb{P}^{reconst}_{N, \alpha}(p)$ function:
# $$
# \mathbb{P}^{reconst}_{N, \alpha}(p) = exp[q_{N, \alpha} + {a_{N, \alpha}p + b_{N, \alpha} p^2 + c_{N, \alpha} p^3} + d_{N, \alpha} p^4 + e_{N, \alpha} p^5 + f_{N, \alpha} p^6]
# $$

# %%
import sys
sys.path.insert(0, '../')

# %%
import critical_noise as CN
import numpy as np
import matplotlib.pyplot as plt
import random
import scipy.optimize

# %% [markdown]
# ## Results obtained from cluster simulations

# %% [markdown]
# The sizes are `[100, 500, 1000, 1300, 2000, 3000]` and the corresponding `nsamples` used are `[10^5, 10^4, 10^4, 10^4, 7*10^3, 2*10^3]`

# %%
NN = [200, 700, 1000, 2000]
α = 0.15
_, _, pc013, dpc013 =  CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= True, plot_reg=True, x_guess = 0.05, dret = 6, dfss = 2)

# %%
NN = [200, 700, 1000, 1500]
α = 0.14
_, _, pc013, dpc013 =  CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= True, plot_reg=True, x_guess = 0.1, dret = 7, dfss = 2)

# %%
NN = [200, 700, 1000, 1500]
α = 0.13
_, _, pc013, dpc013 =  CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg=True, x_guess = 0.18, dret = 4, dfss = 2)

# %%
NN = [200, 700, 1000, 1500]
α = 0.12
_, _, pc012, dpc012 =  CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg=True, x_guess = 0.22, dret = 4, dfss = 2)

# %%
NN = [200, 700, 1000, 1500]
α = 0.11
_, _, pc011, dpc011 =  CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg=True, x_guess = 0.27, dret = 4, dfss = 2)

# %%
NN = [200, 700, 1000, 1500]
α = 0.1
_, _, pc01, dpc01 =  CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= False, plot_reg=True, x_guess = 0.3, dret = 4, dfss = 2)

# %%
NN = [200, 700, 1000, 1500]
α = 0.09
_, _, pc009, dpc009 =  CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit = False, plot_reg=True, x_guess = 0.33, dret = 4, dfss = 2)

# %%
NN = [200, 700, 1000, 1500]
α = 0.08
_, _, pc008, dpc008 =  CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit = False, plot_reg=True, x_guess = 0.35, dret = 4, dfss = 2)

# %%
NN = [200, 700, 1000, 1500]
α = 0.07
_, _, pc007, dpc007 =  CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit = False, plot_reg=True, x_guess = 0.37, dret = 4, dfss = 2)

# %%
NN = [200, 700, 1000, 1500]
α = 0.06
_, _, pc006, dpc006 =  CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit = False, plot_reg=True, x_guess = 0.4, dret = 4, dfss = 2)

# %%
NN = [200, 700, 1000, 1500]
α = 0.05
_, _, pc005, dpc005 =  CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit = False, plot_reg=True, x_guess = 0.4, dret = 5, dfss = 2)

# %%
NN = [200, 700, 1000, 1500]
α = 0.04
_, _, pc004, dpc004 =  CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit = False, plot_reg=True, x_guess = 0.4, dret = 4, dfss = 2)

# %%
NN = [200, 700, 1000]
α = 0.03
_, _, pc003, dpc003 =  CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit = True, plot_reg=True, x_guess = 0.5, dret = 5, dfss = 2)
# Out:
# /Users/lorenzomancini/Desktop/Physics of Data/Thesis/codes/src/Standard Hopfield/Critical Noise/notebooks/../critical_noise.py:90: RuntimeWarning: overflow encountered in exp
#   root = fsolve(lambda x: np.exp(sum([p*(x**i) for i, p in enumerate(popt)])) - thr, x_guess)
# /Users/lorenzomancini/Desktop/Physics of Data/Thesis/codes/src/Standard Hopfield/Critical Noise/notebooks/../critical_noise.py:8: RuntimeWarning: invalid value encountered in reciprocal
#   return sum([p*(x**(-i)) for i, p in enumerate(params)])
# /Users/lorenzomancini/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
NN = [200, 600, 1000]
α = 0.02
_, _, pc002, dpc002 =  CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data/old/corr_0",
              plot_fit = False, plot_reg=True, x_guess = 0.5, dret = 4, dfss = 2)
# Out:
# /Users/lorenzomancini/Desktop/Physics of Data/Thesis/codes/src/Standard Hopfield/Critical Noise/notebooks/../critical_noise.py:8: RuntimeWarning: invalid value encountered in reciprocal
#   return sum([p*(x**(-i)) for i, p in enumerate(params)])
# /Users/lorenzomancini/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
y = [pc004, pc005, pc006, pc007, pc008, pc009, pc01, pc011, pc012, pc013]
dy = [dpc004, dpc005, dpc006, dpc007, dpc008, dpc009, dpc01, dpc011, dpc012, dpc013]
x = [0.04, 0.05, 0.06, 0.07, 0.08, 0.09, 0.1, 0.11, 0.12, 0.13]

size = 12
plt.plot(x, y, marker = "o", color = "green", markerfacecolor = "None", linestyle = "None",
         label = "radius")
plt.xlabel(r"$\alpha$", size = size)
plt.ylabel(r"$p_c(\alpha)$", size = size)
plt.grid(axis = "both", linestyle = "--", alpha = 0.5)
plt.legend(fontsize = size)
plt.show()

# %%
dy
# Out:
# [0.0002846872833304929,
#  0.00016446543394144994,
#  1.5074876391880089e-05,
#  0.0003303798115789238,
#  0.0003955535932110967,
#  0.00012033479309147923,
#  0.00073768808759392,
#  0.0006441549740647967,
#  0.0015955035703469778,
#  0.0004817702627930497]

# %%
dd = [(0.06, range(0.22, 0.52, length = 22)),
             (0.05, range(0.24, 0.54, length = 22)),
             (0.04, range(0.26, 0.54, length = 22)),
             (0.03, range(0.30, 0.56, length = 22)),
             (0.02, range(0.32, 0.57, length = 22)),
     (0.07, range(0.20, 0.50, length = 22)),
     (0.08, range(0.20, 0.52, length = 22))]
