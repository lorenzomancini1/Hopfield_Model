# %%
import sys
sys.path.insert(0, '../../../')

import find_critical_alpha as CA
import numpy as np
import matplotlib.pyplot as plt

# %%
q = "09"
NN = [500, 800, 1000, 1200, 2000]
_, _, αc, δαc = CA.compute_critical_alpha(NN, rootdir = "./", datadir = "julia_data/q_"+q,
               plot_sig = True, plot_scal = True,
               errorbar = True, d = 2, skip = 1)

# %%
αc
# Out:
# 0.1454896773784909

# %%
δαc
# Out:
# 0.00023070052674704057
