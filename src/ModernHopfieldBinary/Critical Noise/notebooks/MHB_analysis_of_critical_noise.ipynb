# %%
import sys
sys.path.insert(0, '../../../../')

# %%
import find_critical_noise as CN
import numpy as np
import matplotlib.pyplot as plt

# %%
x = []
y = []
yerr = []

# %%
λ = "005"
q = "09"
α = 0.01
NN = [100, 120, 150, 180, 200]
_, _, pc001, dpc001 = CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data/q_"+q+"/lambda_"+λ,
              plot_fit= False, plot_reg=True, errorbar = True, d = 1, skip = 1)
x.append(α)
y.append(pc001)
yerr.append(dpc001)

# %%
λ = "005"
q = "09"
α = 0.015
NN = [100, 120, 150, 180, 200]
_, _, pc0015, dpc0015 = CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data/q_"+q+"/lambda_"+λ,
              plot_fit= False, plot_reg=True, errorbar = True, d = 1, skip = 1)
x.append(α)
y.append(pc0015)
yerr.append(dpc0015)

# %%
λ = "005"
q = "09"
α = 0.02
NN = [100, 120, 150, 180, 200]
_, _, pc002, dpc002 = CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data/q_"+q+"/lambda_"+λ,
              plot_fit= False, plot_reg=True, errorbar = True, d = 1, skip = 1)
x.append(α)
y.append(pc002)
yerr.append(dpc002)

# %%
λ = "005"
q = "09"
α = 0.025
NN = [100, 120, 150, 180, 200]
_, _, pc0025, dpc0025 = CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data/q_"+q+"/lambda_"+λ,
              plot_fit= False, plot_reg=True, errorbar = True, d = 1, skip = 1)
x.append(α)
y.append(pc0025)
yerr.append(dpc0025)

# %%
λ = "005"
q = "09"
α = 0.03
NN = [100, 120, 150, 180, 200]
_, _, pc003, dpc003 = CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data/q_"+q+"/lambda_"+λ,
              plot_fit= False, plot_reg=True, errorbar = True, d = 1, skip = 1)
x.append(α)
y.append(pc003)
yerr.append(dpc003)

# %%
λ = "005"
q = "09"
α = 0.035
NN = [100, 120, 150, 180, 200]
_, _, pc0035, dpc0035 = CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data/q_"+q+"/lambda_"+λ,
              plot_fit= False, plot_reg=True, errorbar = True, d = 1, skip = 1)
x.append(α)
y.append(pc0035)
yerr.append(dpc0035)

# %%
λ = "005"
q = "09"
α = 0.04
NN = [100, 120, 150, 180, 200]
_, _, pc004, dpc004 = CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data/q_"+q+"/lambda_"+λ,
              plot_fit= False, plot_reg=True, errorbar = True, d = 1, skip = 1)
x.append(α)
y.append(pc004)
yerr.append(dpc004)

# %%
λ = "005"
q = "09"
α = 0.045
NN = [100, 120, 150, 180, 200]
_, _, pc0045, dpc0045 = CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data/q_"+q+"/lambda_"+λ,
              plot_fit= False, plot_reg=True, errorbar = True, d = 1, skip = 1)
x.append(α)
y.append(pc0045)
yerr.append(dpc0045)

# %%
λ = "005"
q = "09"
α = 0.05
NN = [100, 120, 130, 150, 180]
_, _, pc005, dpc005 = CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data/q_"+q+"/lambda_"+λ,
              plot_fit= False, plot_reg=True, errorbar = True, d = 1, skip = 1)
x.append(α)
y.append(pc005)
yerr.append(dpc005)

# %%
λ = "005"
q = "09"
α = 0.055
NN = [70, 90, 100, 120, 150]
_, _, pc0055, dpc0055 = CN.compute_critical_noise(α, NN, rootdir = "./", datadir = "julia_data/q_"+q+"/lambda_"+λ,
              plot_fit= True, plot_reg=True, errorbar = True, d = 2, skip = 1)
x.append(α)
y.append(pc0055)
yerr.append(dpc0055)

# %%
plt.plot(x, y, marker = "o", linestyle = "None", color = "green")
