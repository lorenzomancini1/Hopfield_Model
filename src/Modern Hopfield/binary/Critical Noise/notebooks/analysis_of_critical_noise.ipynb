# %%
import sys
sys.path.insert(0, '../')

# %%
import critical_noise as CN
import numpy as np
import matplotlib.pyplot as plt

# %%
NN = [20, 30, 40, 80]
α = 100
_, pc100 = CN.compute_pc(α, NN, rootdir = "../", datadir = "julia_data/reconstruction_prob",
              plot_fit= False, plot_reg=True, x_guess = 0.31, thr = 0.5, xi = 0.3, xf = 0.7)

# %%
NN = [20, 40, 80, 100]
α = 10
_, pc10 = CN.compute_pc(α, NN, rootdir = "../", datadir = "julia_data/reconstruction_prob",
              plot_fit= True, plot_reg=True, x_guess = 0.31, thr = 0.5, xi = 0.3, xf = 0.7)
