# %%
import sys
sys.path.insert(0, '../')

# %%
import critical_noise as CN
import numpy as np
import matplotlib.pyplot as plt

# %%
NN = [50, 60, 80]
α = 0.1
_, _, pc006, dpc006 = CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= True, plot_reg=True, x_guess = 0.31)
# Out:
# /Users/lorenzomancini/Desktop/Physics of Data/Thesis/codes/src/Modern Hopfield/binary/Critical Noise/notebooks/../critical_noise.py:8: RuntimeWarning: invalid value encountered in reciprocal
#   return sum([p*(x**(-i)) for i, p in enumerate(params)])
# /Users/lorenzomancini/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
NN = [20, 40, 80, 100]
α = 10
_, pc10 = CN.compute_pc(α, NN, rootdir = "../", datadir = "julia_data/reconstruction_prob",
              plot_fit= True, plot_reg=True, x_guess = 0.31, thr = 0.5, xi = 0.3, xf = 0.7)
