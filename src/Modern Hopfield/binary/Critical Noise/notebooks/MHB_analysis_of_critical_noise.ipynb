# %%
import sys
sys.path.insert(0, '../')

# %%
import critical_noise as CN
import numpy as np
import matplotlib.pyplot as plt

# %%
λ = "005"
α = 0.02
NN = [50, 100, 150, 200]
_, _, pc002, dpc002 = CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data/lambda_"+λ,
              plot_fit= False, plot_reg=True, x_guess = 0.4, d1 = 3)
# Out:
# /Users/lorenzomancini/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
λ = "005"
α = 0.025
NN = [50, 100, 150, 200]
_, _, pc0025, dpc025 = CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data/lambda_"+λ,
              plot_fit= False, plot_reg=True, x_guess = 0.35, d1 = 2)

# %%
λ = "005"
α = 0.03
NN = [50, 100, 150, 200]
_, _, pc003, dpc003 = CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data/lambda_"+λ,
              plot_fit= False, plot_reg=True, x_guess = 0.35, d1 = 3)
# Out:
# /Users/lorenzomancini/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
λ = "005"
α = 0.035
NN = [50, 100, 150, 200]
_, _, pc0035, dpc0035 = CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data/lambda_"+λ,
              plot_fit= True, plot_reg=True, x_guess = 0.32, d1 = 3)
# Out:
# /Users/lorenzomancini/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
λ = "005"
α = 0.04
NN = [50, 100, 150, 200]
_, _, pc004, dpc004 = CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data/lambda_"+λ,
              plot_fit= True, plot_reg=True, x_guess = 0.28, d1 = 3)
# Out:
# /Users/lorenzomancini/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
λ = "005"
α = 0.045
NN = [40, 60, 90, 120]
_, _, pc01, dpc01 = CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data/lambda_"+λ,
              plot_fit= False, plot_reg=True, x_guess = 0.25, d1 = 3)
# Out:
# /Users/lorenzomancini/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %% [markdown]
# NN = [50, 60, 70, 80]
# α = 0.12
# λ = "02"
# _, _, pc01, dpc01 = CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data/lambda_"+λ,
#               plot_fit= True, plot_reg=True, x_guess = 0.31)

# %% [markdown]
# NN = [50, 60, 70, 80, 90]
# α = 0.08
# λ = "02"
# _, _, pc01, dpc01 = CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data/lambda_"+λ,
#               plot_fit= True, plot_reg=True, x_guess = 0.31)

# %% [markdown]
# NN = [50, 60, 70, 80, 90]
# α = 0.09
# λ = "02"
# _, _, pc006, dpc006 = CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data/lambda_"+λ,
#               plot_fit= True, plot_reg=True, x_guess = 0.31)

# %% [markdown]
# NN = [50, 60, 70, 80, 90]
# α = 0.08
# λ = "02"
# _, _, pc006, dpc006 = CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data/lambda_"+λ,
#               plot_fit= True, plot_reg=True, x_guess = 0.31)

# %% [markdown]
# NN = [50, 60, 70, 80, 90]
# α = 0.07
# λ = "02"
# _, _, pc006, dpc006 = CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data/lambda_"+λ,
#               plot_fit= True, plot_reg=True, x_guess = 0.31)

# %% [markdown]
# NN = [50, 60, 70, 80, 90]
# α = 0.06
# λ = "02"
# _, _, pc006, dpc006 = CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data/lambda_"+λ,
#               plot_fit= True, plot_reg=True, x_guess = 0.31)

# %%
dd = [(0.1, range(0.12, 0.5, length = 22)), (0.09, range(0.14, 0.51, length = 22)),
     (0.08, range(0.14, 0.53, length = 22)), (0.07, range(0.16, 0.54, length = 22)),
     (0.06, range(0.18, 0.56, length = 22)), (0.12, range(0.12, 0.46, length = 22))]

# %%
λ = "004"
q = "09"
α = 0.04
NN = [50, 80, 100, 150]
_, _, pc004, dpc004 = CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data/q_"+q+"/lambda_"+λ,
              plot_fit= True, plot_reg=True, x_guess = 0.25, d1 = 3)
# Out:
# /Users/lorenzomancini/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
λ = "004"
q = "09"
α = 0.05
NN = [70, 80, 100, 150]
_, _, pc005, dpc005 = CN.compute_pc(α, NN, rootdir = "./", datadir = "julia_data/q_"+q+"/lambda_"+λ,
              plot_fit= True, plot_reg=True, x_guess = 0.12, d1 = 3)
# Out:
# /Users/lorenzomancini/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
P_N.shape
# Out:
# (22,)

# %%
pp = np.loadtxt(rootdir+datadir+"/alpha_"+folder+"/N{}.txt".format(NN[0]), delimiter = "\t", skiprows=1)[:, 0]

# %%
pp.shape
# Out:
# (22,)
