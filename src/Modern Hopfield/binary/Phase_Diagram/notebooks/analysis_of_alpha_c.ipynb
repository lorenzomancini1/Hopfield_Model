# %%
import sys
sys.path.insert(0, '../')

# %%
import finitesize as fs
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Simulations with q = 0.9

# %% [markdown]
# ## $\lambda = 0.03$

# %%
NN = [50, 60, 70, 80, 90]
λ = 0.03
q = "09"
a, b, αc003, dαc003 = fs.compute_αc(λ, NN, rootdir = "./", datadir = "julia_data/q_"+q,
              plot_prob= False, plot_scaling=True, x_guess = 0.045, d0 = 6)

# %%
λ = 0.03
λ - np.log(np.cosh(λ))
# Out:
# 0.02955006748380445

# %% [markdown]
# ## $\lambda = 0.04$

# %%
NN = [50, 60, 70, 80, 90]
λ = 0.04
q = "09"
a, b, αc004, dαc004 = fs.compute_αc(λ, NN, rootdir = "./", datadir = "julia_data/q_"+q,
              plot_prob= True, plot_scaling=True, x_guess = 0.05, d0 = 6)

# %% [markdown]
# ## $\lambda = 0.05$

# %%
NN = [50, 60, 70, 80, 90]
λ = 0.05
q = "09"
a, b, αc005, dαc005 = fs.compute_αc(λ, NN, rootdir = "./", datadir = "julia_data/q_"+q,
              plot_prob= False, plot_scaling=True, x_guess = 0.065, d0 = 6)

# %%
λ = 0.05
λ - np.log(np.cosh(λ))
# Out:
# 0.04875052048637438

# %% [markdown]
# ## $\lambda = 0.06$

# %%
NN = [40, 50, 60, 80, 90]
λ = 0.06
q = "09"
a, b, αc006, dαc006 = fs.compute_αc(λ, NN, rootdir = "./", datadir = "julia_data/q_"+q,
              plot_prob= False, plot_scaling=True, x_guess = 0.08, d0 = 6)

# %% [markdown]
# ## $\lambda = 0.07$

# %%
NN = [40, 50, 60, 80]
λ = 0.07
q = "09"
a, b, αc007, dαc007 = fs.compute_αc(λ, NN, rootdir = "./", datadir = "julia_data/q_"+q,
              plot_prob= False, plot_scaling=True, x_guess = 0.09, d0 = 5)

# %% [markdown]
# ## $\lambda = 0.08$

# %%
NN = [50, 60, 70, 80]
λ = 0.08
q = "09"
a, b, αc008, dαc008 = fs.compute_αc(λ, NN, rootdir = "./", datadir = "julia_data/q_"+q,
              plot_prob= False, plot_scaling=True, x_guess = 0.1, d0 = 5)

# %%
λ = 0.08
λ - np.log(np.cosh(λ))
# Out:
# 0.07680340751920556

# %% [markdown]
# ## $\lambda = 0.09$

# %%
NN = [50, 60, 70]
λ = 0.09
q = "09"
a, b, αc009, dαc009 = fs.compute_αc(λ, NN, rootdir = "./", datadir = "julia_data/q_"+q,
              plot_prob= False, plot_scaling=True, x_guess = 0.12, d0 = 5)
# Out:
# /Users/lorenzomancini/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
λ = 0.09
λ - np.log(np.cosh(λ))
# Out:
# 0.08595545571916338

# %% [markdown]
# ## $\lambda = 0.1$

# %%
NN = [30, 40, 50]
λ = 0.1
q = "09"
a, b, αc01, dαc01 = fs.compute_αc(λ, NN, rootdir = "./", datadir = "julia_data/q_"+q,
              plot_prob= False, plot_scaling=True, x_guess = 0.14, d0 = 5)
# Out:
# /Users/lorenzomancini/anaconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %% [markdown]
# NN = [20, 25, 30, 35]
# λ = 0.2
# a, b, αc02, dαc02 = fs.compute_αc(λ, NN, rootdir = "./", datadir = "julia_data",
#               plot_prob= True, plot_scaling=True, x_guess = 0.25, d0 = 6)
#
# λ = 0.2
# λ - np.log(np.cosh(λ))

# %%
αc = [αc003, αc004, αc005, αc008, αc01]
λ = [0.03, 0.04, 0.05, 0.08, 0.1]
x = np.linspace(0.03, 0.1, 300)
y = x - np.log(np.cosh(x))

plt.plot(λ, αc, marker = "o", markerfacecolor = "None", linestyle = "--", c = "green", label = "experimental values")
plt.plot(x, y, c ="red", label = "theoretical values")
plt.grid(axis = "both", alpha = 0.5, linestyle = "--")
plt.xlabel("λ")
plt.ylabel("α")
plt.legend()
plt.show()

# %% [markdown]
# # Simulations with q = 1.0

# %%
NN = [50, 60, 70, 80, 90]
λ = 0.04
q = "10" # i.e. select the folder corresponding to q = 1.0
a, b, αc004, dαc004 = fs.compute_αc(λ, NN, rootdir = "./", datadir = "julia_data/q_"+q,
              plot_prob= True, plot_scaling=True, x_guess = 0.05, d0 = 6)

# %%
λ = 0.04
λ - np.log(np.cosh(λ))
# Out:
# 0.039200213242355265

# %%
NN = [50, 60, 70, 80]
λ = 0.05
q = "10"
a, b, αc005, dαc005 = fs.compute_αc(λ, NN, rootdir = "./", datadir = "julia_data/q_"+q,
              plot_prob= True, plot_scaling=True, x_guess = 0.067, d0 = 4)
