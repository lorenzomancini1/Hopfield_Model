# %%
import sys
sys.path.insert(0, '../')

# %%
import finitesize as fs
import numpy as np
import matplotlib.pyplot as plt

# %%
NN = [40, 50, 60, 70, 80, 90]
λ = 0.05
a, b, αc005, dαc006 = fs.compute_αc(λ, NN, rootdir = "./", datadir = "julia_data",
              plot_fit= True, plot_reg=True, x_guess = 0.065, dret = 6)

# %%
λ = 0.05
λ - np.log(np.cosh(λ))
# Out:
# 0.04875052048637438
