# %%
include("../alpha_critical.jl")
# Out:
# simulate_escape (generic function with 1 method)

# %% [markdown]
# # $\lambda = 0.1$

# %%
λ = 0.1
λ - log(cosh(λ))
# Out:
# 0.09500831117835357

# %%
NN = [(30, 1000)]
dd = [(0.1, range(0.03, 0.21, length = 15))]
@time simulate_escape(NN, dd; show = true, save = false)
# Out:
# ------------------λ = 0.1------------------
# N = 30 ---> Done!
#  29.490150 seconds (7.63 M allocations: 16.243 GiB, 13.34% gc time)

# %%
NN = [(40, 100)]
dd = [(0.1, range(0.06, 0.21, length = 15))]
@time simulate_escape(NN, dd; show = true, save = false)
# Out:
# ------------------λ = 0.1------------------
# N = 40 ---> Done!
# 224.120024 seconds (6.89 M allocations: 85.143 GiB, 7.60% gc time)

# %%
# Out:
# 0.09500831117835357

# %% [markdown]
# # $\lambda = 0.05$

# %%
λ = 0.05
λ - log(cosh(λ))
# Out:
# 0.04875052048637438

# %%
NN = [(30, 1000)]
dd = [(0.05, range(0.007, 0.12, length = 15))]
@time simulate_escape(NN, dd; show = true, save = false)
# Out:
# ------------------λ = 0.05------------------
# N = 30 ---> Done!
#   1.888315 seconds (5.58 M allocations: 1.098 GiB, 12.08% gc time)

# %%
NN = [(40, 1000)]
dd = [(0.05, range(0.007, 0.12, length = 15))]
@time simulate_escape(NN, dd; show = true, save = false)
# Out:
# ------------------λ = 0.05------------------
# N = 40 ---> Done!
#  10.547822 seconds (11.23 M allocations: 5.852 GiB, 10.88% gc time)

# %% [markdown]
# # Histograms

# %%
λ = 0.1
α1 = 
α2 =
α3 =
