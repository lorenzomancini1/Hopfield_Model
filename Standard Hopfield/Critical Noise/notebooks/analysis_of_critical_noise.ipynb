# %% [markdown]
# We define the critical probability as
# $$
# p_c(N, \alpha) := \left\{p: \mathbb{P}^{reconst}_{N, \alpha}(p) = \frac{1}{2} \right\},
# $$
# that is, the corruption probability such that the reconstruction probability is equal to 0.5. <br>
# Thus, taking the $\lim_{N \to \infty}$, we define:
# $$
# p_c(\alpha) = \lim_{N \to \infty} p_c(N, \alpha).
# $$
# Assuming that $ p_c(N, \alpha) \sim 1/N $, i.e.
# $$
# p_c(N, \alpha) = p_c(\alpha) + \frac{1}{N} p_c(\alpha) + o\left(\frac{1}{N^2}\right)
# $$
# **our goal is to determine $p_c(\alpha)$**.<br>
# In order to achieve this, we need to fit the $\mathbb{P}^{reconst}_{N, \alpha}(p)$ function:
# $$
# \mathbb{P}^{reconst}_{N, \alpha}(p) = exp[q_{N, \alpha} + {a_{N, \alpha}p + b_{N, \alpha} p^2 + c_{N, \alpha} p^3} + d_{N, \alpha} p^4]
# $$

# %% [markdown]
# ## $p_c$ for $\alpha$ = 0.1

# %%
import sys
sys.path.insert(0, '../')

# %%
import critical_noise as CN

# %%
NN = [50, 100, 150, 200, 1000, 1500]
α = 0.1
CN.compute_pc(α, NN, rootdir = "../", datadir = "workstation_data", plot_fit= True, plot_reg = True)
# Out:
# ([0.3436897001310192,
#   0.33114229244294635,
#   0.3255034033289097,
#   0.3223361777866531,
#   0.31432922710363326,
#   0.31408895493098415],
#  0.3124076797226874)

# %%
NN = [100, 200, 300, 400, 500, 700, 1000]
α = 0.09
CN.compute_pc(α, NN, rootdir = "../", datadir = "workstation_data", plot_fit= True, plot_reg = True)
# Out:
# ([0.3487557376500495,
#   0.3431251168730727,
#   0.34082610037354083,
#   0.33931576842472505,
#   0.3384770114203595,
#   0.3374727688063551,
#   0.33710942831346313],
#  0.33511059529010767)

# %%
NN = [100, 200, 300, 400, 500, 700]
α = 0.08
CN.compute_pc(α, NN, rootdir = "../", datadir = "workstation_data", plot_fit= True, plot_reg = True)
# Out:
# ([0.363518131422556,
#   0.3612255789035089,
#   0.35890775554411053,
#   0.3582983258101365,
#   0.3572891758387308,
#   0.35746435664569],
#  0.3549888882931989)

# %%
NN = [100, 200, 300, 400, 500]
α = 0.07
CN.compute_pc(α, NN, rootdir = "../", datadir = "workstation_data", plot_fit = False, plot_reg = True)
# Out:
# ([0.37580859223719176,
#   0.3781166866322392,
#   0.37750206100216793,
#   0.37604225128812213,
#   0.3760082159337799],
#  0.37269966835554336)

# %%
NN = [100, 200, 300, 400, 500]
α = 0.06
CN.compute_pc(α, NN, rootdir = "../", datadir = "workstation_data", plot_fit = False, plot_reg = True)
# Out:
# ([0.3870175438148212,
#   0.3930966468212844,
#   0.39292375250211703,
#   0.3932309912423957,
#   0.3927020203721979],
#  0.39101568564858014)

# %%
NN = [100, 200, 300, 400, 500]
α = 0.06
CN.compute_pc(α, NN, rootdir = "../", datadir = "workstation_data", plot_fit = False, plot_reg = True)
# Out:
# ([0.3870175438148212,
#   0.3930966468212844,
#   0.39292375250211703,
#   0.3932309912423957,
#   0.3927020203721979],
#  0.39101568564858014)

# %%
NN = [100, 200, 300, 400, 500]
α = 0.05
CN.compute_pc(α, NN, rootdir = "../", datadir = "workstation_data", plot_fit = False, plot_reg = True)
# Out:
# ([0.39796695966215545,
#   0.40611667508351235,
#   0.4082714870549049,
#   0.4082531181415129,
#   0.40843724845343043],
#  0.40886668793442654)

# %%
NN = [100, 200, 300, 400, 500]
α = 0.04
CN.compute_pc(α, NN, rootdir = "../", datadir = "workstation_data", plot_fit = False, plot_reg = True)
# Out:
# ([0.4118770454064424,
#   0.41557212176107816,
#   0.4207942345676569,
#   0.42250891634315274,
#   0.42324794355938095],
#  0.43107383931599175)

# %%
NN = [100, 200, 300, 400, 500]
α = 0.03
CN.compute_pc(α, NN, rootdir = "../", datadir = "workstation_data", plot_fit = False, plot_reg = True)
# Out:
# ([0.4299551175363499,
#   0.42439632087645635,
#   0.4312592718333799,
#   0.43495817024382627,
#   0.43658459302871094],
#  0.4519200688573628)
